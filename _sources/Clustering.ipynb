# %% [markdown]
# # **Algoritma *K-Means***

# %% [markdown]
# ## **Pengertian *K-Means Clustering***
#
# K-Means Clustering merupakan metode untuk mengelompokkan data dengan cara memisahkannya ke dalam beberapa cluster. Teknik ini bekerja dengan menempatkan data yang memiliki kesamaan fitur ke dalam kelompok yang sama, sedangkan data yang memiliki karakteristik berbeda dikelompokkan ke dalam cluster lain. Proses pengelompokan ini dilakukan dengan menggunakan titik pusat (centroid) sebagai acuan dalam menentukan pembagian cluster, sehingga data yang mirip berada dalam satu cluster, dan data yang berbeda tersebar di cluster lain.
#
#
# ## **Manfaat *Clustering***
#
#
# - Clustering adalah teknik segmentasi data yang sangat bermanfaat untuk keperluan prediksi dan analisis berbagai permasalahan bisnis. Contohnya dapat diterapkan dalam segmentasi pasar, strategi pemasaran, serta pemetaan wilayah berdasarkan zona tertentu.
# - Pengenalan objek digunakan dalam berbagai bidang, seperti computer vision dan pemrosesan citra.
#
# Clustering yang efektif akan menghasilkan kelompok dengan tingkat kemiripan yang tinggi di dalam satu cluster dan tingkat kemiripan yang rendah antar cluster. Kemiripan ini diukur secara numerik antara dua objek. Semakin mirip dua objek yang dibandingkan, semakin tinggi nilai kesamaannya, dan sebaliknya, semakin berbeda objek tersebut, maka nilai kesamaannya akan rendah. Kualitas dari hasil clustering sangat dipengaruhi oleh metode yang digunakan dalam proses pengelompokannya.

# %% [markdown]
# ## **Inertia (Sum Square error/SSE)**
#
#
# Dalam konteks algoritma *K-Means Clustering*, *inertia* (Sum Square error/SSE) adalah salah satu metrik evaluasi untuk menilai seberapa baik data dikelompokkan ke dalam klaster serta mengukur jumlah total jarak kuadrat antara setiap titik data dan pusat klaster (centroid) tempat titik tersebut.
#
# Inertia didefinisikan sebagai:
#
# $$
# \text{Inertia} = \sum_{i=1}^{n} \left\| x_i - \mu_{c_i} \right\|^2
# $$
#
# **Penjelasan Notasi**
# - $x_i$: Titik data ke-$i$
# - $\mu_{c_i}$: Centroid dari klaster tempat $x_i$ berada
# - $\left\| x_i - \mu_{c_i} \right\|^2$: Jarak Euclidean kuadrat antara $x_i$ dan centroid-nya
# - $n$: Jumlah total data

# %% [markdown]
# ## **Silhouette Analysis**
#
#
# Silhouette Analysis adalah metrik evaluasi lain yang lebih baik dari inertia dalam banyak kasus untuk mengevaluasi hasil clustering, seperti pada K-Means, karena mempertimbangkan dua hal sekaligus yaitu:
#
# - Kepadatan dalam klaster
#
# - Jarak antar klaster
#
# Silhouette Analysis mengukur seberapa mirip suatu titik data dengan klasternya sendiri dibandingkan dengan klaster terdekat lainnya. Rumusnya adalah:
#
# $$
# s(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}
# $$
#
# **Penjelasan Notasi**:
# - $a(i)$: Rata-rata jarak dari titik $i$ ke semua titik lain dalam klaster yang sama (cohesion)
# - $b(i)$: Rata-rata jarak dari titik $i$ ke semua titik dalam klaster terdekat yang bukan miliknya (separation)
# - $s(i)$: Skor silhouette untuk titik $i$, dengan nilai antara -1 dan 1
#
# Nilai skor $s(i)$ ditafsirkan sebagai berikut:
# - Jika $s(i) \approx 1$, maka titik berada jauh dari klaster lain dan cocok dengan klasternya
# - Jika $s(i) \approx 0$, maka titik berada di antara dua klaster
# - Jika $s(i) \approx -1$, maka titik bisa jadi salah masuk klaster
#
# Untuk mengevaluasi seluruh hasil clustering, digunakan rata-rata dari semua $s(i)$:
#
# $$
# S = \frac{1}{n} \sum_{i=1}^{n} s(i)
# $$
#
# - $n$: Jumlah total data
# - $S$: Silhouette score rata-rata seluruh data

# %% [markdown]
# ## **Implementasi untuk data Iris**

# %%
# %pip install pymysql
# %pip install psycopg2
# Out:
# Requirement already satisfied: pymysql in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.11/dist-packages (2.9.10)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import silhouette_score
import psycopg2
import pymysql
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## **Pengumpulan Data**

# %%
def get_pg_data():
    conn = psycopg2.connect(
        host="ndik-anugrahs15042004-79e6.d.aivencloud.com",
        user="avnadmin",
        password="AVNS_7FsJrvmsNJPSkv0qE-1",
        database="defaultdb",
        port=18856
    )
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM sepal")
    data = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]  # Ambil nama kolom
    cursor.close()
    conn.close()

    return pd.DataFrame(data, columns=columns)

def get_mysql_data():
    conn = pymysql.connect(
        host="mulyono-anugrahs15042004-79e6.d.aivencloud.com",
        user="avnadmin",
        password="AVNS_UrgkI5rl3s3AFs4zUkw",
        database="iris",
        port=18856
    )
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM petal")
    data = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]  # Ambil nama kolom
    cursor.close()
    conn.close()

    return pd.DataFrame(data, columns=columns)

# Ambil data dari kedua database
df_postgresql = get_pg_data()
df_mysql = get_mysql_data()

# Gabungkan berdasarkan kolom 'id' dan 'Class'
df_merged = pd.merge(df_mysql, df_postgresql, on=["id", "class"], how="inner")

# Cetak semua data hasil gabungan tanpa indeks
print(df_merged.to_string(index=False))
# Out:
#  id           class  petal_length  petal_width  sepal_length  sepal_width
#   1     Iris-setosa          15.6         32.4          20.3         25.7
#   2     Iris-setosa          14.0          2.0          40.9         30.0
#   3     Iris-setosa           1.3          0.2           4.7          3.2
#   4     Iris-setosa           1.5          0.2           4.6          3.1
#   5     Iris-setosa           1.4          0.2           5.0          3.6
#   6     Iris-setosa           1.7          0.4           5.4          3.9
#   7     Iris-setosa           1.4          0.3           4.6          3.4
#   8     Iris-setosa           1.5          0.2           5.0          3.4
#   9     Iris-setosa           1.4          0.2           4.4          2.9
#  10     Iris-setosa          24.2         13.4          33.2         24.1
#  11     Iris-setosa           1.5          0.2           5.4          3.7
#  12     Iris-setosa           1.6          0.2           4.8          3.4
#  13     Iris-setosa           1.4          0.1           4.8          3.0
#  14     Iris-setosa           1.1          0.1           4.3          3.0
#  15     Iris-setosa           1.2          0.2           5.8          4.0
#  16     Iris-setosa           1.5          0.4           5.7          4.4
#  17     Iris-setosa           1.3          0.4           5.4          3.9
#  18     Iris-setosa           1.4          0.3           5.1          3.5
#  19     Iris-setosa           1.7          0.3           5.7          3.8
#  20     Iris-setosa          21.3         13.1          11.4         15.0
#  21     Iris-setosa           1.7          0.2           5.4          3.4
#  22     Iris-setosa           1.5          0.4           5.1          3.7
#  23     Iris-setosa           1.0          0.2           4.6          3.6
#  24     Iris-setosa           1.7          0.5           5.1          3.3
#  25     Iris-setosa           1.9          0.2           4.8          3.4
#  26     Iris-setosa           1.6          0.2           5.0          3.0
#  27     Iris-setosa           1.6          0.4           5.0          3.4
#  28     Iris-setosa           1.5          0.2           5.2          3.5
#  29     Iris-setosa           1.4          0.2           5.2          3.4
#  30     Iris-setosa          48.3         26.7          43.6         14.3
#  31     Iris-setosa           1.6          0.2           4.8          3.1
#  32     Iris-setosa           1.5          0.4           5.4          3.4
#  33     Iris-setosa           1.5          0.1           5.2          4.1
#  34     Iris-setosa           1.4          0.2           5.5          4.2
#  35     Iris-setosa           1.5          0.1           4.9          3.1
#  36     Iris-setosa           1.2          0.2           5.0          3.2
#  37     Iris-setosa           1.3          0.2           5.5          3.5
#  38     Iris-setosa           1.5          0.1           4.9          3.1
#  39     Iris-setosa           1.3          0.2           4.4          3.0
#  40     Iris-setosa          55.8         23.0          33.0         22.7
#  41     Iris-setosa           1.3          0.3           5.0          3.5
#  42     Iris-setosa           1.3          0.3           4.5          2.3
#  43     Iris-setosa           1.3          0.2           4.4          3.2
#  44     Iris-setosa           1.6          0.6           5.0          3.5
#  45     Iris-setosa           1.9          0.4           5.1          3.8
#  46     Iris-setosa           1.4          0.3           4.8          3.0
#  47     Iris-setosa           1.6          0.2           5.1          3.8
#  48     Iris-setosa           1.4          0.2           4.6          3.2
#  49     Iris-setosa           1.5          0.2           5.3          3.7
#  50     Iris-setosa          43.0         25.0          21.4         20.0
#  51 Iris-versicolor           4.7          1.4           7.0          3.2
#  52 Iris-versicolor           4.5          1.5           6.4          3.2
#  53 Iris-versicolor           4.9          1.5           6.9          3.1
#  54 Iris-versicolor           4.0          1.3           5.5          2.3
#  55 Iris-versicolor           4.6          1.5           6.5          2.8
#  56 Iris-versicolor           4.5          1.3           5.7          2.8
#  57 Iris-versicolor           4.7          1.6           6.3          3.3
#  58 Iris-versicolor           3.3          1.0           4.9          2.4
#  59 Iris-versicolor           4.6          1.3           6.6          2.9
#  60 Iris-versicolor          27.0         44.0          44.0         32.9
#  61 Iris-versicolor           3.5          1.0           5.0          2.0
#  62 Iris-versicolor           4.2          1.5           5.9          3.0
#  63 Iris-versicolor           4.0          1.0           6.0          2.2
#  64 Iris-versicolor           4.7          1.4           6.1          2.9
#  65 Iris-versicolor           3.6          1.3           5.6          2.9
#  66 Iris-versicolor           4.4          1.4           6.7          3.1
#  67 Iris-versicolor           4.5          1.5           5.6          3.0
#  68 Iris-versicolor           4.1          1.0           5.8          2.7
#  69 Iris-versicolor           4.5          1.5           6.2          2.2
#  70 Iris-versicolor          20.5         40.0          26.7         35.0
#  71 Iris-versicolor           4.8          1.8           5.9          3.2
#  72 Iris-versicolor           4.0          1.3           6.1          2.8
#  73 Iris-versicolor           4.9          1.5           6.3          2.5
#  74 Iris-versicolor           4.7          1.2           6.1          2.8
#  75 Iris-versicolor           4.3          1.3           6.4          2.9
#  76 Iris-versicolor           4.4          1.4           6.6          3.0
#  77 Iris-versicolor           4.8          1.4           6.8          2.8
#  78 Iris-versicolor           5.0          1.7           6.7          3.0
#  79 Iris-versicolor           4.5          1.5           6.0          2.9
#  80 Iris-versicolor          32.0         54.0          22.0         16.9
#  81 Iris-versicolor           3.8          1.1           5.5          2.4
#  82 Iris-versicolor           3.7          1.0           5.5          2.4
#  83 Iris-versicolor           3.9          1.2           5.8          2.7
#  84 Iris-versicolor           5.1          1.6           6.0          2.7
#  85 Iris-versicolor           4.5          1.5           5.4          3.0
#  86 Iris-versicolor           4.5          1.6           6.0          3.4
#  87 Iris-versicolor           4.7          1.5           6.7          3.1
#  88 Iris-versicolor           4.4          1.3           6.3          2.3
#  89 Iris-versicolor           4.1          1.3           5.6          3.0
#  90 Iris-versicolor          41.0         62.2          44.0         22.7
#  91 Iris-versicolor           4.4          1.2           5.5          2.6
#  92 Iris-versicolor           4.6          1.4           6.1          3.0
#  93 Iris-versicolor           4.0          1.2           5.8          2.6
#  94 Iris-versicolor           3.3          1.0           5.0          2.3
#  95 Iris-versicolor           4.2          1.3           5.6          2.7
#  96 Iris-versicolor           4.2          1.2           5.7          3.0
#  97 Iris-versicolor           4.2          1.3           5.7          2.9
#  98 Iris-versicolor           4.3          1.3           6.2          2.9
#  99 Iris-versicolor           3.0          1.1           5.1          2.5
# 100 Iris-versicolor          43.0         27.6          44.7         33.6
# 101  Iris-virginica           6.0          2.5           6.3          3.3
# 102  Iris-virginica           5.1          1.9           5.8          2.7
# 103  Iris-virginica           5.9          2.1           7.1          3.0
# 104  Iris-virginica           5.6          1.8           6.3          2.9
# 105  Iris-virginica           5.8          2.2           6.5          3.0
# 106  Iris-virginica           6.6          2.1           7.6          3.0
# 107  Iris-virginica           4.5          1.7           4.9          2.5
# 108  Iris-virginica           6.3          1.8           7.3          2.9
# 109  Iris-virginica           5.8          1.8           6.7          2.5
# 110  Iris-virginica           6.1          2.5           7.2          3.6
# 111  Iris-virginica           5.1          2.0           6.5          3.2
# 112  Iris-virginica           5.3          1.9           6.4          2.7
# 113  Iris-virginica           5.5          2.1           6.8          3.0
# 114  Iris-virginica           5.0          2.0           5.7          2.5
# 115  Iris-virginica           5.1          2.4           5.8          2.8
# 116  Iris-virginica           5.3          2.3           6.4          3.2
# 117  Iris-virginica           5.5          1.8           6.5          3.0
# 118  Iris-virginica           6.7          2.2           7.7          3.8
# 119  Iris-virginica           6.9          2.3           7.7          2.6
# 120  Iris-virginica           5.0          1.5           6.0          2.2
# 121  Iris-virginica           5.7          2.3           6.9          3.2
# 122  Iris-virginica           4.9          2.0           5.6          2.8
# 123  Iris-virginica           6.7          2.0           7.7          2.8
# 124  Iris-virginica           4.9          1.8           6.3          2.7
# 125  Iris-virginica           5.7          2.1           6.7          3.3
# 126  Iris-virginica           6.0          1.8           7.2          3.2
# 127  Iris-virginica           4.8          1.8           6.2          2.8
# 128  Iris-virginica           4.9          1.8           6.1          3.0
# 129  Iris-virginica           5.6          2.1           6.4          2.8
# 130  Iris-virginica           5.8          1.6           7.2          3.0
# 131  Iris-virginica           6.1          1.9           7.4          2.8
# 132  Iris-virginica           6.4          2.0           7.9          3.8
# 133  Iris-virginica           5.6          2.2           6.4          2.8
# 134  Iris-virginica           5.1          1.5           6.3          2.8
# 135  Iris-virginica           5.6          1.4           6.1          2.6
# 136  Iris-virginica           6.1          2.3           7.7          3.0
# 137  Iris-virginica           5.6          2.4           6.3          3.4
# 138  Iris-virginica           5.5          1.8           6.4          3.1
# 139  Iris-virginica           4.8          1.8           6.0          3.0
# 140  Iris-virginica           5.4          2.1           6.9          3.1
# 141  Iris-virginica           5.6          2.4           6.7          3.1
# 142  Iris-virginica           5.1          2.3           6.9          3.1
# 143  Iris-virginica           5.1          1.9           5.8          2.7
# 144  Iris-virginica           5.9          2.3           6.8          3.2
# 145  Iris-virginica           5.7          2.5           6.7          3.3
# 146  Iris-virginica           5.2          2.3           6.7          3.0
# 147  Iris-virginica           5.0          1.9           6.3          2.5
# 148  Iris-virginica           5.2          2.0           6.5          3.0
# 149  Iris-virginica           5.4          2.3           6.2          3.4
# 150  Iris-virginica           5.1          1.8           5.9          3.0

# %% [markdown]
# ## **Clustering pada data Iris menggunakan K-Means dengan jumlah cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_cols].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi clustering
def perform_kmeans(X_scaled, y, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    centroids = kmeans.cluster_centers_
    accuracy = adjusted_rand_score(y, labels)

    print(f"\nHasil K-Means dengan {k} Klaster:")
    print(f"Centroids:\n{centroids}")
    print(f"Akurasi (Adjusted Rand Score): {accuracy:.3f}")

    return labels, centroids, accuracy

# 4. Jalankan clustering
for k in [2, 3, 4]:
    perform_kmeans(X_scaled, y, k)
# Out:
# Hasil K-Means dengan 2 Klaster:
# Centroids:
# [[-0.26342958 -0.26471231 -0.24581264 -0.24282931]
#  [ 3.32879194  3.34500102  3.10617787  3.06847946]]
# Akurasi (Adjusted Rand Score): 0.004
#
# Hasil K-Means dengan 3 Klaster:
# Centroids:
# [[-0.26849937 -0.27873375 -0.2602409  -0.25208248]
#  [ 4.33793787  3.34114419  4.24447237  3.59532423]
#  [ 2.19474628  3.10850515  2.09869743  2.40153738]]
# Akurasi (Adjusted Rand Score): 0.004
#
# Hasil K-Means dengan 4 Klaster:
# Centroids:
# [[-0.26849937 -0.27873375 -0.2602409  -0.25208248]
#  [ 4.26940771  3.44475947  4.30257957  2.90347049]
#  [ 2.26153802  3.29654338  1.95240206  1.88965605]
#  [ 3.20302716  2.45347939  3.49425659  5.91778228]]
# Akurasi (Adjusted Rand Score): 0.004

# %% [markdown]
# ## **Model Plotting dengan Jumlah Cluster 2, 3 dan 4**

# %%
# baruuuuu
# 1. Siapkan fitur (X) dan label (y)
feature_cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_cols].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk melakukan K-Means, plotting dan menampilkan centroid
def perform_kmeans_plot(X_scaled, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)

    # Centroid dari masing-masing klaster
    centroids = kmeans.cluster_centers_

    # Plotting data dan centroid
    plt.figure(figsize=(8, 6))

    # Scatter plot untuk 2 fitur pertama (sepal length & sepal width)
    plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='Set1', marker='o', edgecolors='k', s=100)

    # Plot centroid dengan warna berbeda
    plt.scatter(centroids[:, 0], centroids[:, 1], c='black', marker='X', s=200, label='Centroids')

    plt.title(f"K-Means Clustering with {k} Clusters")
    plt.xlabel(feature_cols[0])  # Ganti dari feature_names ke feature_cols
    plt.ylabel(feature_cols[1])  # Ganti dari feature_names ke feature_cols
    plt.legend()
    plt.show()

# 4. Melakukan clustering dengan K=2, K=3, dan K=4 dan plot hasilnya
for k in [2, 3, 4]:
    perform_kmeans_plot(X_scaled, k)

# %% [markdown]
# ## **Menghitung Inertia untuk Jumlah Cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_cols].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk menghitung inertia secara manual
def calculate_inertia_step_by_step(X_scaled, labels, centroids):
    inertia = 0
    print("Langkah-langkah perhitungan Inertia:")

    for i in range(len(X_scaled)):
        cluster = labels[i]
        distance = np.linalg.norm(X_scaled[i] - centroids[cluster]) ** 2
        inertia += distance
        print(f"Titik data {i+1} (Fitur: {X_scaled[i]}), Klaster: {cluster}, "
              f"Centroid: {centroids[cluster]}, Jarak kuadrat: {distance:.3f}, "
              f"Inertia sementara: {inertia:.3f}")

    return inertia

# 4. Fungsi untuk menjalankan KMeans dan menghitung inertia manual
def perform_kmeans(X_scaled, y, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    centroids = kmeans.cluster_centers_

    print(f"\n=== Hasil K-Means dengan {k} Klaster ===")
    print(f"Centroids (fitur hasil standarisasi):\n{centroids}")

    # Hitung inertia manual
    manual_inertia = calculate_inertia_step_by_step(X_scaled, labels, centroids)
    print(f"\nTotal Inertia Manual: {manual_inertia:.3f}")

    # Bandingkan dengan inertia dari sklearn
    sklearn_inertia = kmeans.inertia_
    print(f"Inertia dari sklearn: {sklearn_inertia:.3f}")
    print("="*50)

    return labels, centroids, manual_inertia

# 5. Jalankan untuk k=2, 3, dan 4
for k in [2, 3, 4]:
    perform_kmeans(X_scaled, y, k)
# Out:
# === Hasil K-Means dengan 2 Klaster ===
# Centroids (fitur hasil standarisasi):
# [[-0.26342958 -0.26471231 -0.24581264 -0.24282931]
#  [ 3.32879194  3.34500102  3.10617787  3.06847946]]
# Langkah-langkah perhitungan Inertia:
# Titik data 1 (Fitur: [1.57623641 3.41620408 1.08942378 3.1286621 ]), Klaster: 1, Centroid: [3.32879194 3.34500102 3.10617787 3.06847946], Jarak kuadrat: 7.147, Inertia sementara: 7.147
# Titik data 2 (Fitur: [ 4.21496786  4.11785088  0.90532175 -0.17053064]), Klaster: 1, Centroid: [3.32879194 3.34500102 3.10617787 3.06847946], Jarak kuadrat: 16.718, Inertia sementara: 23.865
# Titik data 3 (Fitur: [-0.42202624 -0.25520363 -0.55598814 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.137, Inertia sementara: 24.002
# Titik data 4 (Fitur: [-0.43483562 -0.271521   -0.53297539 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.127, Inertia sementara: 24.129
# Titik data 5 (Fitur: [-0.38359811 -0.18993416 -0.54448176 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.124, Inertia sementara: 24.253
# Titik data 6 (Fitur: [-0.33236061 -0.14098206 -0.50996263 -0.34417237]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.100, Inertia sementara: 24.353
# Titik data 7 (Fitur: [-0.43483562 -0.22256889 -0.54448176 -0.35502497]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.133, Inertia sementara: 24.486
# Titik data 8 (Fitur: [-0.38359811 -0.22256889 -0.53297539 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.114, Inertia sementara: 24.600
# Titik data 9 (Fitur: [-0.46045437 -0.30415573 -0.54448176 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.145, Inertia sementara: 24.745
# Titik data 10 (Fitur: [3.22864591 3.1551262  2.07897221 1.06666664]), Klaster: 1, Centroid: [3.32879194 3.34500102 3.10617787 3.06847946], Jarak kuadrat: 5.108, Inertia sementara: 29.853
# Titik data 11 (Fitur: [-0.33236061 -0.17361679 -0.53297539 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.111, Inertia sementara: 29.964
# Titik data 12 (Fitur: [-0.40921686 -0.22256889 -0.52146901 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.114, Inertia sementara: 30.078
# Titik data 13 (Fitur: [-0.40921686 -0.28783836 -0.54448176 -0.37673019]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.129, Inertia sementara: 30.207
# Titik data 14 (Fitur: [-0.47326374 -0.28783836 -0.57900089 -0.37673019]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.174, Inertia sementara: 30.380
# Titik data 15 (Fitur: [-0.2811231  -0.12466469 -0.56749452 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.139, Inertia sementara: 30.519
# Titik data 16 (Fitur: [-0.29393248 -0.05939522 -0.53297539 -0.34417237]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.136, Inertia sementara: 30.655
# Titik data 17 (Fitur: [-0.33236061 -0.14098206 -0.55598814 -0.34417237]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.127, Inertia sementara: 30.781
# Titik data 18 (Fitur: [-0.37078874 -0.20625153 -0.54448176 -0.35502497]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.117, Inertia sementara: 30.898
# Titik data 19 (Fitur: [-0.29393248 -0.15729942 -0.50996263 -0.35502497]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.095, Inertia sementara: 30.993
# Titik data 20 (Fitur: [0.43620195 1.67024575 1.74528727 1.03410881]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 9.829, Inertia sementara: 40.821
# Titik data 21 (Fitur: [-0.33236061 -0.22256889 -0.50996263 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.091, Inertia sementara: 40.913
# Titik data 22 (Fitur: [-0.37078874 -0.17361679 -0.53297539 -0.34417237]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.113, Inertia sementara: 41.025
# Titik data 23 (Fitur: [-0.43483562 -0.18993416 -0.59050727 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.169, Inertia sementara: 41.194
# Titik data 24 (Fitur: [-0.37078874 -0.23888626 -0.50996263 -0.33331976]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.090, Inertia sementara: 41.284
# Titik data 25 (Fitur: [-0.40921686 -0.22256889 -0.48694988 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.096, Inertia sementara: 41.381
# Titik data 26 (Fitur: [-0.38359811 -0.28783836 -0.52146901 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.106, Inertia sementara: 41.487
# Titik data 27 (Fitur: [-0.38359811 -0.22256889 -0.52146901 -0.34417237]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.102, Inertia sementara: 41.589
# Titik data 28 (Fitur: [-0.35797936 -0.20625153 -0.53297539 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.110, Inertia sementara: 41.699
# Titik data 29 (Fitur: [-0.35797936 -0.22256889 -0.54448176 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.115, Inertia sementara: 41.814
# Titik data 30 (Fitur: [4.56082101 1.55602417 4.85200908 2.51006346]), Klaster: 1, Centroid: [3.32879194 3.34500102 3.10617787 3.06847946], Jarak kuadrat: 8.078, Inertia sementara: 49.892
# Titik data 31 (Fitur: [-0.40921686 -0.271521   -0.52146901 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.112, Inertia sementara: 50.005
# Titik data 32 (Fitur: [-0.33236061 -0.22256889 -0.53297539 -0.34417237]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.099, Inertia sementara: 50.104
# Titik data 33 (Fitur: [-0.35797936 -0.10834732 -0.53297539 -0.37673019]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.134, Inertia sementara: 50.238
# Titik data 34 (Fitur: [-0.31955123 -0.09202995 -0.54448176 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.137, Inertia sementara: 50.375
# Titik data 35 (Fitur: [-0.39640749 -0.271521   -0.53297539 -0.37673019]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.118, Inertia sementara: 50.493
# Titik data 36 (Fitur: [-0.38359811 -0.25520363 -0.56749452 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.133, Inertia sementara: 50.627
# Titik data 37 (Fitur: [-0.31955123 -0.20625153 -0.55598814 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.118, Inertia sementara: 50.744
# Titik data 38 (Fitur: [-0.39640749 -0.271521   -0.53297539 -0.37673019]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.118, Inertia sementara: 50.863
# Titik data 39 (Fitur: [-0.46045437 -0.28783836 -0.55598814 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.151, Inertia sementara: 51.013
# Titik data 40 (Fitur: [3.20302716 2.92668305 5.71498736 2.10851698]), Klaster: 1, Centroid: [3.32879194 3.34500102 3.10617787 3.06847946], Jarak kuadrat: 7.918, Inertia sementara: 58.931
# Titik data 41 (Fitur: [-0.38359811 -0.20625153 -0.55598814 -0.35502497]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.127, Inertia sementara: 59.058
# Titik data 42 (Fitur: [-0.44764499 -0.40205994 -0.55598814 -0.35502497]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.162, Inertia sementara: 59.220
# Titik data 43 (Fitur: [-0.46045437 -0.25520363 -0.55598814 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.150, Inertia sementara: 59.370
# Titik data 44 (Fitur: [-0.38359811 -0.20625153 -0.52146901 -0.32246715]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.100, Inertia sementara: 59.470
# Titik data 45 (Fitur: [-0.37078874 -0.15729942 -0.48694988 -0.34417237]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.091, Inertia sementara: 59.562
# Titik data 46 (Fitur: [-0.40921686 -0.28783836 -0.54448176 -0.35502497]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.124, Inertia sementara: 59.685
# Titik data 47 (Fitur: [-0.37078874 -0.15729942 -0.52146901 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.114, Inertia sementara: 59.799
# Titik data 48 (Fitur: [-0.43483562 -0.25520363 -0.54448176 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.134, Inertia sementara: 59.933
# Titik data 49 (Fitur: [-0.34516998 -0.17361679 -0.53297539 -0.36587758]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.113, Inertia sementara: 60.046
# Titik data 50 (Fitur: [1.71713955 2.48611413 4.2421711  2.32556913]), Klaster: 1, Centroid: [3.32879194 3.34500102 3.10617787 3.06847946], Jarak kuadrat: 5.178, Inertia sementara: 65.223
# Titik data 51 (Fitur: [-0.12741059 -0.25520363 -0.16477132 -0.23564629]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.025, Inertia sementara: 65.249
# Titik data 52 (Fitur: [-0.20426685 -0.25520363 -0.18778407 -0.22479368]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.007, Inertia sementara: 65.256
# Titik data 53 (Fitur: [-0.14021997 -0.271521   -0.14175857 -0.22479368]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.026, Inertia sementara: 65.282
# Titik data 54 (Fitur: [-0.31955123 -0.40205994 -0.24531596 -0.2464989 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.022, Inertia sementara: 65.304
# Titik data 55 (Fitur: [-0.19145747 -0.3204731  -0.1762777  -0.22479368]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.013, Inertia sementara: 65.318
# Titik data 56 (Fitur: [-0.29393248 -0.3204731  -0.18778407 -0.2464989 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.007, Inertia sementara: 65.325
# Titik data 57 (Fitur: [-0.21707622 -0.23888626 -0.16477132 -0.21394107]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.010, Inertia sementara: 65.335
# Titik data 58 (Fitur: [-0.39640749 -0.38574257 -0.3258606  -0.27905672]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.040, Inertia sementara: 65.375
# Titik data 59 (Fitur: [-0.1786481  -0.30415573 -0.1762777  -0.2464989 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.014, Inertia sementara: 65.389
# Titik data 60 (Fitur: [4.61205851 4.59105454 2.40115077 4.38756459]), Klaster: 1, Centroid: [3.32879194 3.34500102 3.10617787 3.06847946], Jarak kuadrat: 5.436, Inertia sementara: 70.825
# Titik data 61 (Fitur: [-0.38359811 -0.45101204 -0.30284784 -0.27905672]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.054, Inertia sementara: 70.879
# Titik data 62 (Fitur: [-0.26831373 -0.28783836 -0.2223032  -0.22479368]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.001, Inertia sementara: 70.881
# Titik data 63 (Fitur: [-0.25550435 -0.4183773  -0.24531596 -0.27905672]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.025, Inertia sementara: 70.906
# Titik data 64 (Fitur: [-0.24269498 -0.30415573 -0.16477132 -0.23564629]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.009, Inertia sementara: 70.914
# Titik data 65 (Fitur: [-0.30674186 -0.30415573 -0.29134147 -0.2464989 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.006, Inertia sementara: 70.920
# Titik data 66 (Fitur: [-0.16583872 -0.271521   -0.19929045 -0.23564629]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.012, Inertia sementara: 70.931
# Titik data 67 (Fitur: [-0.30674186 -0.28783836 -0.18778407 -0.22479368]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.006, Inertia sementara: 70.938
# Titik data 68 (Fitur: [-0.2811231  -0.33679047 -0.23380958 -0.27905672]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.007, Inertia sementara: 70.945
# Titik data 69 (Fitur: [-0.2298856  -0.4183773  -0.18778407 -0.22479368]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.028, Inertia sementara: 70.973
# Titik data 70 (Fitur: [2.39603647 4.93371926 1.65323626 3.95346028]), Klaster: 1, Centroid: [3.32879194 3.34500102 3.10617787 3.06847946], Jarak kuadrat: 6.288, Inertia sementara: 77.261
# Titik data 71 (Fitur: [-0.26831373 -0.25520363 -0.15326494 -0.19223586]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.011, Inertia sementara: 77.273
# Titik data 72 (Fitur: [-0.24269498 -0.3204731  -0.24531596 -0.2464989 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.004, Inertia sementara: 77.276
# Titik data 73 (Fitur: [-0.21707622 -0.3694252  -0.14175857 -0.22479368]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.024, Inertia sementara: 77.300
# Titik data 74 (Fitur: [-0.24269498 -0.3204731  -0.16477132 -0.2573515 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.010, Inertia sementara: 77.311
# Titik data 75 (Fitur: [-0.20426685 -0.30415573 -0.21079683 -0.2464989 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.006, Inertia sementara: 77.317
# Titik data 76 (Fitur: [-0.1786481  -0.28783836 -0.19929045 -0.23564629]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.010, Inertia sementara: 77.327
# Titik data 77 (Fitur: [-0.15302934 -0.3204731  -0.15326494 -0.23564629]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.024, Inertia sementara: 77.351
# Titik data 78 (Fitur: [-0.16583872 -0.28783836 -0.13025219 -0.20308847]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.025, Inertia sementara: 77.376
# Titik data 79 (Fitur: [-0.25550435 -0.30415573 -0.18778407 -0.22479368]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.005, Inertia sementara: 77.381
# Titik data 80 (Fitur: [1.7939958  1.98027573 2.97646962 5.47282536]), Klaster: 1, Centroid: [3.32879194 3.34500102 3.10617787 3.06847946], Jarak kuadrat: 10.016, Inertia sementara: 87.397
# Titik data 81 (Fitur: [-0.31955123 -0.38574257 -0.26832871 -0.26820411]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.019, Inertia sementara: 87.416
# Titik data 82 (Fitur: [-0.31955123 -0.38574257 -0.27983509 -0.27905672]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.020, Inertia sementara: 87.436
# Titik data 83 (Fitur: [-0.2811231  -0.33679047 -0.25682234 -0.2573515 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.006, Inertia sementara: 87.442
# Titik data 84 (Fitur: [-0.25550435 -0.33679047 -0.11874581 -0.21394107]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.022, Inertia sementara: 87.464
# Titik data 85 (Fitur: [-0.33236061 -0.28783836 -0.18778407 -0.22479368]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.009, Inertia sementara: 87.473
# Titik data 86 (Fitur: [-0.25550435 -0.22256889 -0.18778407 -0.21394107]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.006, Inertia sementara: 87.479
# Titik data 87 (Fitur: [-0.16583872 -0.271521   -0.16477132 -0.22479368]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.016, Inertia sementara: 87.496
# Titik data 88 (Fitur: [-0.21707622 -0.40205994 -0.19929045 -0.2464989 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.023, Inertia sementara: 87.519
# Titik data 89 (Fitur: [-0.30674186 -0.28783836 -0.23380958 -0.2464989 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.003, Inertia sementara: 87.521
# Titik data 90 (Fitur: [4.61205851 2.92668305 4.01204355 6.36273919]), Klaster: 1, Centroid: [3.32879194 3.34500102 3.10617787 3.06847946], Jarak kuadrat: 13.495, Inertia sementara: 101.016
# Titik data 91 (Fitur: [-0.31955123 -0.35310783 -0.19929045 -0.2573515 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.013, Inertia sementara: 101.029
# Titik data 92 (Fitur: [-0.24269498 -0.28783836 -0.1762777  -0.23564629]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.006, Inertia sementara: 101.035
# Titik data 93 (Fitur: [-0.2811231  -0.35310783 -0.24531596 -0.2573515 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.008, Inertia sementara: 101.043
# Titik data 94 (Fitur: [-0.38359811 -0.40205994 -0.3258606  -0.27905672]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.041, Inertia sementara: 101.084
# Titik data 95 (Fitur: [-0.30674186 -0.33679047 -0.2223032  -0.2464989 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.008, Inertia sementara: 101.092
# Titik data 96 (Fitur: [-0.29393248 -0.28783836 -0.2223032  -0.2573515 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.002, Inertia sementara: 101.094
# Titik data 97 (Fitur: [-0.29393248 -0.30415573 -0.2223032  -0.2464989 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.003, Inertia sementara: 101.097
# Titik data 98 (Fitur: [-0.2298856  -0.30415573 -0.21079683 -0.2464989 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.004, Inertia sementara: 101.101
# Titik data 99 (Fitur: [-0.37078874 -0.3694252  -0.36037973 -0.26820411]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.036, Inertia sementara: 101.138
# Titik data 100 (Fitur: [4.70172415 4.70527612 4.2421711  2.60773693]), Klaster: 1, Centroid: [3.32879194 3.34500102 3.10617787 3.06847946], Jarak kuadrat: 5.238, Inertia sementara: 106.376
# Titik data 101 (Fitur: [-0.21707622 -0.23888626 -0.01518842 -0.1162676 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.072, Inertia sementara: 106.448
# Titik data 102 (Fitur: [-0.2811231  -0.33679047 -0.11874581 -0.18138325]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.025, Inertia sementara: 106.473
# Titik data 103 (Fitur: [-0.11460122 -0.28783836 -0.02669479 -0.15967803]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.078, Inertia sementara: 106.551
# Titik data 104 (Fitur: [-0.21707622 -0.30415573 -0.06121393 -0.19223586]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.040, Inertia sementara: 106.591
# Titik data 105 (Fitur: [-0.19145747 -0.28783836 -0.03820117 -0.14882543]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.058, Inertia sementara: 106.649
# Titik data 106 (Fitur: [-0.05055434 -0.28783836  0.05384984 -0.15967803]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.143, Inertia sementara: 106.791
# Titik data 107 (Fitur: [-0.39640749 -0.3694252  -0.18778407 -0.20308847]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.034, Inertia sementara: 106.825
# Titik data 108 (Fitur: [-0.08898247 -0.30415573  0.01933071 -0.19223586]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.105, Inertia sementara: 106.930
# Titik data 109 (Fitur: [-0.16583872 -0.3694252  -0.03820117 -0.19223586]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.066, Inertia sementara: 106.996
# Titik data 110 (Fitur: [-0.10179184 -0.18993416 -0.00368204 -0.1162676 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.106, Inertia sementara: 107.102
# Titik data 111 (Fitur: [-0.19145747 -0.25520363 -0.11874581 -0.17053064]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.027, Inertia sementara: 107.129
# Titik data 112 (Fitur: [-0.20426685 -0.33679047 -0.09573306 -0.18138325]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.035, Inertia sementara: 107.164
# Titik data 113 (Fitur: [-0.15302934 -0.28783836 -0.0727203  -0.15967803]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.050, Inertia sementara: 107.213
# Titik data 114 (Fitur: [-0.29393248 -0.3694252  -0.13025219 -0.17053064]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.030, Inertia sementara: 107.244
# Titik data 115 (Fitur: [-0.2811231  -0.3204731  -0.11874581 -0.12712021]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.033, Inertia sementara: 107.277
# Titik data 116 (Fitur: [-0.20426685 -0.25520363 -0.09573306 -0.13797282]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.037, Inertia sementara: 107.314
# Titik data 117 (Fitur: [-0.19145747 -0.28783836 -0.0727203  -0.19223586]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.038, Inertia sementara: 107.352
# Titik data 118 (Fitur: [-0.03774496 -0.15729942  0.06535622 -0.14882543]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.168, Inertia sementara: 107.520
# Titik data 119 (Fitur: [-0.03774496 -0.35310783  0.08836898 -0.13797282]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.181, Inertia sementara: 107.702
# Titik data 120 (Fitur: [-0.25550435 -0.4183773  -0.13025219 -0.22479368]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.037, Inertia sementara: 107.739
# Titik data 121 (Fitur: [-0.14021997 -0.25520363 -0.04970755 -0.13797282]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.065, Inertia sementara: 107.804
# Titik data 122 (Fitur: [-0.30674186 -0.3204731  -0.14175857 -0.17053064]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.021, Inertia sementara: 107.825
# Titik data 123 (Fitur: [-0.03774496 -0.3204731   0.06535622 -0.17053064]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.156, Inertia sementara: 107.981
# Titik data 124 (Fitur: [-0.21707622 -0.33679047 -0.14175857 -0.19223586]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.021, Inertia sementara: 108.002
# Titik data 125 (Fitur: [-0.16583872 -0.23888626 -0.04970755 -0.15967803]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.056, Inertia sementara: 108.057
# Titik data 126 (Fitur: [-0.10179184 -0.25520363 -0.01518842 -0.19223586]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.082, Inertia sementara: 108.139
# Titik data 127 (Fitur: [-0.2298856  -0.3204731  -0.15326494 -0.19223586]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.015, Inertia sementara: 108.155
# Titik data 128 (Fitur: [-0.24269498 -0.28783836 -0.14175857 -0.19223586]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.014, Inertia sementara: 108.169
# Titik data 129 (Fitur: [-0.20426685 -0.3204731  -0.06121393 -0.15967803]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.048, Inertia sementara: 108.217
# Titik data 130 (Fitur: [-0.10179184 -0.28783836 -0.03820117 -0.21394107]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.071, Inertia sementara: 108.287
# Titik data 131 (Fitur: [-0.07617309 -0.3204731  -0.00368204 -0.18138325]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.101, Inertia sementara: 108.388
# Titik data 132 (Fitur: [-0.01212621 -0.15729942  0.03083709 -0.17053064]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.156, Inertia sementara: 108.544
# Titik data 133 (Fitur: [-0.20426685 -0.3204731  -0.06121393 -0.14882543]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.050, Inertia sementara: 108.594
# Titik data 134 (Fitur: [-0.21707622 -0.3204731  -0.11874581 -0.22479368]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.022, Inertia sementara: 108.615
# Titik data 135 (Fitur: [-0.24269498 -0.35310783 -0.06121393 -0.23564629]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.042, Inertia sementara: 108.658
# Titik data 136 (Fitur: [-0.03774496 -0.28783836 -0.00368204 -0.13797282]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.121, Inertia sementara: 108.779
# Titik data 137 (Fitur: [-0.21707622 -0.22256889 -0.06121393 -0.12712021]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.051, Inertia sementara: 108.830
# Titik data 138 (Fitur: [-0.20426685 -0.271521   -0.0727203  -0.19223586]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.036, Inertia sementara: 108.866
# Titik data 139 (Fitur: [-0.25550435 -0.28783836 -0.15326494 -0.19223586]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.012, Inertia sementara: 108.878
# Titik data 140 (Fitur: [-0.14021997 -0.271521   -0.08422668 -0.15967803]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.048, Inertia sementara: 108.926
# Titik data 141 (Fitur: [-0.16583872 -0.271521   -0.06121393 -0.12712021]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.057, Inertia sementara: 108.983
# Titik data 142 (Fitur: [-0.14021997 -0.271521   -0.11874581 -0.13797282]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.042, Inertia sementara: 109.026
# Titik data 143 (Fitur: [-0.2811231  -0.33679047 -0.11874581 -0.18138325]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.025, Inertia sementara: 109.051
# Titik data 144 (Fitur: [-0.15302934 -0.25520363 -0.02669479 -0.13797282]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.071, Inertia sementara: 109.122
# Titik data 145 (Fitur: [-0.16583872 -0.23888626 -0.04970755 -0.1162676 ]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.065, Inertia sementara: 109.187
# Titik data 146 (Fitur: [-0.16583872 -0.28783836 -0.10723943 -0.13797282]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.040, Inertia sementara: 109.227
# Titik data 147 (Fitur: [-0.21707622 -0.3694252  -0.13025219 -0.18138325]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.030, Inertia sementara: 109.258
# Titik data 148 (Fitur: [-0.19145747 -0.28783836 -0.10723943 -0.17053064]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.030, Inertia sementara: 109.288
# Titik data 149 (Fitur: [-0.2298856  -0.22256889 -0.08422668 -0.13797282]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.040, Inertia sementara: 109.328
# Titik data 150 (Fitur: [-0.26831373 -0.28783836 -0.11874581 -0.19223586]), Klaster: 0, Centroid: [-0.26342958 -0.26471231 -0.24581264 -0.24282931], Jarak kuadrat: 0.019, Inertia sementara: 109.347
#
# Total Inertia Manual: 109.347
# Inertia dari sklearn: 109.347
# ==================================================
#
# === Hasil K-Means dengan 3 Klaster ===
# Centroids (fitur hasil standarisasi):
# [[-0.26849937 -0.27873375 -0.2602409  -0.25208248]
#  [ 4.33793787  3.34114419  4.24447237  3.59532423]
#  [ 2.19474628  3.10850515  2.09869743  2.40153738]]
# Langkah-langkah perhitungan Inertia:
# Titik data 1 (Fitur: [1.57623641 3.41620408 1.08942378 3.1286621 ]), Klaster: 2, Centroid: [2.19474628 3.10850515 2.09869743 2.40153738], Jarak kuadrat: 2.025, Inertia sementara: 2.025
# Titik data 2 (Fitur: [ 4.21496786  4.11785088  0.90532175 -0.17053064]), Klaster: 2, Centroid: [2.19474628 3.10850515 2.09869743 2.40153738], Jarak kuadrat: 13.140, Inertia sementara: 15.164
# Titik data 3 (Fitur: [-0.42202624 -0.25520363 -0.55598814 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.125, Inertia sementara: 15.289
# Titik data 4 (Fitur: [-0.43483562 -0.271521   -0.53297539 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.115, Inertia sementara: 15.404
# Titik data 5 (Fitur: [-0.38359811 -0.18993416 -0.54448176 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.115, Inertia sementara: 15.519
# Titik data 6 (Fitur: [-0.33236061 -0.14098206 -0.50996263 -0.34417237]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.094, Inertia sementara: 15.613
# Titik data 7 (Fitur: [-0.43483562 -0.22256889 -0.54448176 -0.35502497]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.122, Inertia sementara: 15.735
# Titik data 8 (Fitur: [-0.38359811 -0.22256889 -0.53297539 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.104, Inertia sementara: 15.839
# Titik data 9 (Fitur: [-0.46045437 -0.30415573 -0.54448176 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.131, Inertia sementara: 15.970
# Titik data 10 (Fitur: [3.22864591 3.1551262  2.07897221 1.06666664]), Klaster: 2, Centroid: [2.19474628 3.10850515 2.09869743 2.40153738], Jarak kuadrat: 2.853, Inertia sementara: 18.823
# Titik data 11 (Fitur: [-0.33236061 -0.17361679 -0.53297539 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.102, Inertia sementara: 18.926
# Titik data 12 (Fitur: [-0.40921686 -0.22256889 -0.52146901 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.104, Inertia sementara: 19.030
# Titik data 13 (Fitur: [-0.40921686 -0.28783836 -0.54448176 -0.37673019]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.116, Inertia sementara: 19.146
# Titik data 14 (Fitur: [-0.47326374 -0.28783836 -0.57900089 -0.37673019]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.159, Inertia sementara: 19.305
# Titik data 15 (Fitur: [-0.2811231  -0.12466469 -0.56749452 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.131, Inertia sementara: 19.436
# Titik data 16 (Fitur: [-0.29393248 -0.05939522 -0.53297539 -0.34417237]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.132, Inertia sementara: 19.568
# Titik data 17 (Fitur: [-0.33236061 -0.14098206 -0.55598814 -0.34417237]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.119, Inertia sementara: 19.687
# Titik data 18 (Fitur: [-0.37078874 -0.20625153 -0.54448176 -0.35502497]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.107, Inertia sementara: 19.794
# Titik data 19 (Fitur: [-0.29393248 -0.15729942 -0.50996263 -0.35502497]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.088, Inertia sementara: 19.883
# Titik data 20 (Fitur: [0.43620195 1.67024575 1.74528727 1.03410881]), Klaster: 2, Centroid: [2.19474628 3.10850515 2.09869743 2.40153738], Jarak kuadrat: 7.156, Inertia sementara: 27.038
# Titik data 21 (Fitur: [-0.33236061 -0.22256889 -0.50996263 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.083, Inertia sementara: 27.121
# Titik data 22 (Fitur: [-0.37078874 -0.17361679 -0.53297539 -0.34417237]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.104, Inertia sementara: 27.225
# Titik data 23 (Fitur: [-0.43483562 -0.18993416 -0.59050727 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.158, Inertia sementara: 27.383
# Titik data 24 (Fitur: [-0.37078874 -0.23888626 -0.50996263 -0.33331976]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.081, Inertia sementara: 27.464
# Titik data 25 (Fitur: [-0.40921686 -0.22256889 -0.48694988 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.087, Inertia sementara: 27.551
# Titik data 26 (Fitur: [-0.38359811 -0.28783836 -0.52146901 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.095, Inertia sementara: 27.646
# Titik data 27 (Fitur: [-0.38359811 -0.22256889 -0.52146901 -0.34417237]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.093, Inertia sementara: 27.739
# Titik data 28 (Fitur: [-0.35797936 -0.20625153 -0.53297539 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.101, Inertia sementara: 27.839
# Titik data 29 (Fitur: [-0.35797936 -0.22256889 -0.54448176 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.105, Inertia sementara: 27.944
# Titik data 30 (Fitur: [4.56082101 1.55602417 4.85200908 2.51006346]), Klaster: 1, Centroid: [4.33793787 3.34114419 4.24447237 3.59532423], Jarak kuadrat: 4.783, Inertia sementara: 32.728
# Titik data 31 (Fitur: [-0.40921686 -0.271521   -0.52146901 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.101, Inertia sementara: 32.829
# Titik data 32 (Fitur: [-0.33236061 -0.22256889 -0.53297539 -0.34417237]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.090, Inertia sementara: 32.919
# Titik data 33 (Fitur: [-0.35797936 -0.10834732 -0.53297539 -0.37673019]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.127, Inertia sementara: 33.046
# Titik data 34 (Fitur: [-0.31955123 -0.09202995 -0.54448176 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.131, Inertia sementara: 33.177
# Titik data 35 (Fitur: [-0.39640749 -0.271521   -0.53297539 -0.37673019]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.106, Inertia sementara: 33.283
# Titik data 36 (Fitur: [-0.38359811 -0.25520363 -0.56749452 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.121, Inertia sementara: 33.404
# Titik data 37 (Fitur: [-0.31955123 -0.20625153 -0.55598814 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.108, Inertia sementara: 33.513
# Titik data 38 (Fitur: [-0.39640749 -0.271521   -0.53297539 -0.37673019]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.106, Inertia sementara: 33.619
# Titik data 39 (Fitur: [-0.46045437 -0.28783836 -0.55598814 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.137, Inertia sementara: 33.756
# Titik data 40 (Fitur: [3.20302716 2.92668305 5.71498736 2.10851698]), Klaster: 1, Centroid: [4.33793787 3.34114419 4.24447237 3.59532423], Jarak kuadrat: 5.833, Inertia sementara: 39.589
# Titik data 41 (Fitur: [-0.38359811 -0.20625153 -0.55598814 -0.35502497]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.117, Inertia sementara: 39.706
# Titik data 42 (Fitur: [-0.44764499 -0.40205994 -0.55598814 -0.35502497]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.145, Inertia sementara: 39.851
# Titik data 43 (Fitur: [-0.46045437 -0.25520363 -0.55598814 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.138, Inertia sementara: 39.989
# Titik data 44 (Fitur: [-0.38359811 -0.20625153 -0.52146901 -0.32246715]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.092, Inertia sementara: 40.081
# Titik data 45 (Fitur: [-0.37078874 -0.15729942 -0.48694988 -0.34417237]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.085, Inertia sementara: 40.166
# Titik data 46 (Fitur: [-0.40921686 -0.28783836 -0.54448176 -0.35502497]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.111, Inertia sementara: 40.277
# Titik data 47 (Fitur: [-0.37078874 -0.15729942 -0.52146901 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.106, Inertia sementara: 40.383
# Titik data 48 (Fitur: [-0.43483562 -0.25520363 -0.54448176 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.122, Inertia sementara: 40.505
# Titik data 49 (Fitur: [-0.34516998 -0.17361679 -0.53297539 -0.36587758]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.104, Inertia sementara: 40.610
# Titik data 50 (Fitur: [1.71713955 2.48611413 4.2421711  2.32556913]), Klaster: 2, Centroid: [2.19474628 3.10850515 2.09869743 2.40153738], Jarak kuadrat: 5.216, Inertia sementara: 45.825
# Titik data 51 (Fitur: [-0.12741059 -0.25520363 -0.16477132 -0.23564629]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.030, Inertia sementara: 45.855
# Titik data 52 (Fitur: [-0.20426685 -0.25520363 -0.18778407 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.011, Inertia sementara: 45.866
# Titik data 53 (Fitur: [-0.14021997 -0.271521   -0.14175857 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.031, Inertia sementara: 45.897
# Titik data 54 (Fitur: [-0.31955123 -0.40205994 -0.24531596 -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.018, Inertia sementara: 45.915
# Titik data 55 (Fitur: [-0.19145747 -0.3204731  -0.1762777  -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.015, Inertia sementara: 45.931
# Titik data 56 (Fitur: [-0.29393248 -0.3204731  -0.18778407 -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.008, Inertia sementara: 45.938
# Titik data 57 (Fitur: [-0.21707622 -0.23888626 -0.16477132 -0.21394107]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.015, Inertia sementara: 45.953
# Titik data 58 (Fitur: [-0.39640749 -0.38574257 -0.3258606  -0.27905672]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.033, Inertia sementara: 45.986
# Titik data 59 (Fitur: [-0.1786481  -0.30415573 -0.1762777  -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.016, Inertia sementara: 46.002
# Titik data 60 (Fitur: [4.61205851 4.59105454 2.40115077 4.38756459]), Klaster: 1, Centroid: [4.33793787 3.34114419 4.24447237 3.59532423], Jarak kuadrat: 5.663, Inertia sementara: 51.665
# Titik data 61 (Fitur: [-0.38359811 -0.45101204 -0.30284784 -0.27905672]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.045, Inertia sementara: 51.710
# Titik data 62 (Fitur: [-0.26831373 -0.28783836 -0.2223032  -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.002, Inertia sementara: 51.712
# Titik data 63 (Fitur: [-0.25550435 -0.4183773  -0.24531596 -0.27905672]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.021, Inertia sementara: 51.733
# Titik data 64 (Fitur: [-0.24269498 -0.30415573 -0.16477132 -0.23564629]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.011, Inertia sementara: 51.744
# Titik data 65 (Fitur: [-0.30674186 -0.30415573 -0.29134147 -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.003, Inertia sementara: 51.747
# Titik data 66 (Fitur: [-0.16583872 -0.271521   -0.19929045 -0.23564629]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.015, Inertia sementara: 51.761
# Titik data 67 (Fitur: [-0.30674186 -0.28783836 -0.18778407 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.008, Inertia sementara: 51.769
# Titik data 68 (Fitur: [-0.2811231  -0.33679047 -0.23380958 -0.27905672]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.005, Inertia sementara: 51.774
# Titik data 69 (Fitur: [-0.2298856  -0.4183773  -0.18778407 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.027, Inertia sementara: 51.801
# Titik data 70 (Fitur: [2.39603647 4.93371926 1.65323626 3.95346028]), Klaster: 2, Centroid: [2.19474628 3.10850515 2.09869743 2.40153738], Jarak kuadrat: 5.979, Inertia sementara: 57.780
# Titik data 71 (Fitur: [-0.26831373 -0.25520363 -0.15326494 -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.016, Inertia sementara: 57.795
# Titik data 72 (Fitur: [-0.24269498 -0.3204731  -0.24531596 -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.003, Inertia sementara: 57.798
# Titik data 73 (Fitur: [-0.21707622 -0.3694252  -0.14175857 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.026, Inertia sementara: 57.824
# Titik data 74 (Fitur: [-0.24269498 -0.3204731  -0.16477132 -0.2573515 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.012, Inertia sementara: 57.835
# Titik data 75 (Fitur: [-0.20426685 -0.30415573 -0.21079683 -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.007, Inertia sementara: 57.842
# Titik data 76 (Fitur: [-0.1786481  -0.28783836 -0.19929045 -0.23564629]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.012, Inertia sementara: 57.855
# Titik data 77 (Fitur: [-0.15302934 -0.3204731  -0.15326494 -0.23564629]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.027, Inertia sementara: 57.881
# Titik data 78 (Fitur: [-0.16583872 -0.28783836 -0.13025219 -0.20308847]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.030, Inertia sementara: 57.911
# Titik data 79 (Fitur: [-0.25550435 -0.30415573 -0.18778407 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.007, Inertia sementara: 57.918
# Titik data 80 (Fitur: [1.7939958  1.98027573 2.97646962 5.47282536]), Klaster: 2, Centroid: [2.19474628 3.10850515 2.09869743 2.40153738], Jarak kuadrat: 11.637, Inertia sementara: 69.555
# Titik data 81 (Fitur: [-0.31955123 -0.38574257 -0.26832871 -0.26820411]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.014, Inertia sementara: 69.569
# Titik data 82 (Fitur: [-0.31955123 -0.38574257 -0.27983509 -0.27905672]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.015, Inertia sementara: 69.584
# Titik data 83 (Fitur: [-0.2811231  -0.33679047 -0.25682234 -0.2573515 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.004, Inertia sementara: 69.588
# Titik data 84 (Fitur: [-0.25550435 -0.33679047 -0.11874581 -0.21394107]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.025, Inertia sementara: 69.613
# Titik data 85 (Fitur: [-0.33236061 -0.28783836 -0.18778407 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.010, Inertia sementara: 69.623
# Titik data 86 (Fitur: [-0.25550435 -0.22256889 -0.18778407 -0.21394107]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.010, Inertia sementara: 69.633
# Titik data 87 (Fitur: [-0.16583872 -0.271521   -0.16477132 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.020, Inertia sementara: 69.654
# Titik data 88 (Fitur: [-0.21707622 -0.40205994 -0.19929045 -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.022, Inertia sementara: 69.675
# Titik data 89 (Fitur: [-0.30674186 -0.28783836 -0.23380958 -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.002, Inertia sementara: 69.677
# Titik data 90 (Fitur: [4.61205851 2.92668305 4.01204355 6.36273919]), Klaster: 1, Centroid: [4.33793787 3.34114419 4.24447237 3.59532423], Jarak kuadrat: 7.960, Inertia sementara: 77.637
# Titik data 91 (Fitur: [-0.31955123 -0.35310783 -0.19929045 -0.2573515 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.012, Inertia sementara: 77.649
# Titik data 92 (Fitur: [-0.24269498 -0.28783836 -0.1762777  -0.23564629]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.008, Inertia sementara: 77.657
# Titik data 93 (Fitur: [-0.2811231  -0.35310783 -0.24531596 -0.2573515 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.006, Inertia sementara: 77.663
# ...
# Titik data 70 (Fitur: [2.39603647 4.93371926 1.65323626 3.95346028]), Klaster: 2, Centroid: [2.26153802 3.29654338 1.95240206 1.88965605], Jarak kuadrat: 7.047, Inertia sementara: 54.952
# Titik data 71 (Fitur: [-0.26831373 -0.25520363 -0.15326494 -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.016, Inertia sementara: 54.968
# Titik data 72 (Fitur: [-0.24269498 -0.3204731  -0.24531596 -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.003, Inertia sementara: 54.970
# Titik data 73 (Fitur: [-0.21707622 -0.3694252  -0.14175857 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.026, Inertia sementara: 54.996
# Titik data 74 (Fitur: [-0.24269498 -0.3204731  -0.16477132 -0.2573515 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.012, Inertia sementara: 55.007
# Titik data 75 (Fitur: [-0.20426685 -0.30415573 -0.21079683 -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.007, Inertia sementara: 55.015
# Titik data 76 (Fitur: [-0.1786481  -0.28783836 -0.19929045 -0.23564629]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.012, Inertia sementara: 55.027
# Titik data 77 (Fitur: [-0.15302934 -0.3204731  -0.15326494 -0.23564629]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.027, Inertia sementara: 55.054
# Titik data 78 (Fitur: [-0.16583872 -0.28783836 -0.13025219 -0.20308847]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.030, Inertia sementara: 55.084
# Titik data 79 (Fitur: [-0.25550435 -0.30415573 -0.18778407 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.007, Inertia sementara: 55.090
# Titik data 80 (Fitur: [1.7939958  1.98027573 2.97646962 5.47282536]), Klaster: 3, Centroid: [3.20302716 2.45347939 3.49425659 5.91778228], Jarak kuadrat: 2.675, Inertia sementara: 57.766
# Titik data 81 (Fitur: [-0.31955123 -0.38574257 -0.26832871 -0.26820411]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.014, Inertia sementara: 57.780
# Titik data 82 (Fitur: [-0.31955123 -0.38574257 -0.27983509 -0.27905672]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.015, Inertia sementara: 57.795
# Titik data 83 (Fitur: [-0.2811231  -0.33679047 -0.25682234 -0.2573515 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.004, Inertia sementara: 57.799
# Titik data 84 (Fitur: [-0.25550435 -0.33679047 -0.11874581 -0.21394107]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.025, Inertia sementara: 57.824
# Titik data 85 (Fitur: [-0.33236061 -0.28783836 -0.18778407 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.010, Inertia sementara: 57.834
# Titik data 86 (Fitur: [-0.25550435 -0.22256889 -0.18778407 -0.21394107]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.010, Inertia sementara: 57.844
# Titik data 87 (Fitur: [-0.16583872 -0.271521   -0.16477132 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.020, Inertia sementara: 57.864
# Titik data 88 (Fitur: [-0.21707622 -0.40205994 -0.19929045 -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.022, Inertia sementara: 57.886
# Titik data 89 (Fitur: [-0.30674186 -0.28783836 -0.23380958 -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.002, Inertia sementara: 57.888
# Titik data 90 (Fitur: [4.61205851 2.92668305 4.01204355 6.36273919]), Klaster: 3, Centroid: [3.20302716 2.45347939 3.49425659 5.91778228], Jarak kuadrat: 2.675, Inertia sementara: 60.564
# Titik data 91 (Fitur: [-0.31955123 -0.35310783 -0.19929045 -0.2573515 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.012, Inertia sementara: 60.576
# Titik data 92 (Fitur: [-0.24269498 -0.28783836 -0.1762777  -0.23564629]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.008, Inertia sementara: 60.584
# Titik data 93 (Fitur: [-0.2811231  -0.35310783 -0.24531596 -0.2573515 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.006, Inertia sementara: 60.590
# Titik data 94 (Fitur: [-0.38359811 -0.40205994 -0.3258606  -0.27905672]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.033, Inertia sementara: 60.623
# Titik data 95 (Fitur: [-0.30674186 -0.33679047 -0.2223032  -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.006, Inertia sementara: 60.629
# Titik data 96 (Fitur: [-0.29393248 -0.28783836 -0.2223032  -0.2573515 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.002, Inertia sementara: 60.632
# Titik data 97 (Fitur: [-0.29393248 -0.30415573 -0.2223032  -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.003, Inertia sementara: 60.634
# Titik data 98 (Fitur: [-0.2298856  -0.30415573 -0.21079683 -0.2464989 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.005, Inertia sementara: 60.639
# Titik data 99 (Fitur: [-0.37078874 -0.3694252  -0.36037973 -0.26820411]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.029, Inertia sementara: 60.668
# Titik data 100 (Fitur: [4.70172415 4.70527612 4.2421711  2.60773693]), Klaster: 1, Centroid: [4.26940771 3.44475947 4.30257957 2.90347049], Jarak kuadrat: 1.867, Inertia sementara: 62.535
# Titik data 101 (Fitur: [-0.21707622 -0.23888626 -0.01518842 -0.1162676 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.083, Inertia sementara: 62.618
# Titik data 102 (Fitur: [-0.2811231  -0.33679047 -0.11874581 -0.18138325]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.029, Inertia sementara: 62.646
# Titik data 103 (Fitur: [-0.11460122 -0.28783836 -0.02669479 -0.15967803]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.087, Inertia sementara: 62.733
# Titik data 104 (Fitur: [-0.21707622 -0.30415573 -0.06121393 -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.046, Inertia sementara: 62.779
# Titik data 105 (Fitur: [-0.19145747 -0.28783836 -0.03820117 -0.14882543]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.066, Inertia sementara: 62.845
# Titik data 106 (Fitur: [-0.05055434 -0.28783836  0.05384984 -0.15967803]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.155, Inertia sementara: 63.000
# Titik data 107 (Fitur: [-0.39640749 -0.3694252  -0.18778407 -0.20308847]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.032, Inertia sementara: 63.032
# Titik data 108 (Fitur: [-0.08898247 -0.30415573  0.01933071 -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.115, Inertia sementara: 63.147
# Titik data 109 (Fitur: [-0.16583872 -0.3694252  -0.03820117 -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.072, Inertia sementara: 63.219
# Titik data 110 (Fitur: [-0.10179184 -0.18993416 -0.00368204 -0.1162676 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.120, Inertia sementara: 63.339
# Titik data 111 (Fitur: [-0.19145747 -0.25520363 -0.11874581 -0.17053064]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.033, Inertia sementara: 63.372
# Titik data 112 (Fitur: [-0.20426685 -0.33679047 -0.09573306 -0.18138325]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.040, Inertia sementara: 63.411
# Titik data 113 (Fitur: [-0.15302934 -0.28783836 -0.0727203  -0.15967803]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.057, Inertia sementara: 63.469
# Titik data 114 (Fitur: [-0.29393248 -0.3694252  -0.13025219 -0.17053064]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.032, Inertia sementara: 63.501
# Titik data 115 (Fitur: [-0.2811231  -0.3204731  -0.11874581 -0.12712021]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.038, Inertia sementara: 63.538
# Titik data 116 (Fitur: [-0.20426685 -0.25520363 -0.09573306 -0.13797282]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.045, Inertia sementara: 63.583
# Titik data 117 (Fitur: [-0.19145747 -0.28783836 -0.0727203  -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.045, Inertia sementara: 63.628
# Titik data 118 (Fitur: [-0.03774496 -0.15729942  0.06535622 -0.14882543]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.185, Inertia sementara: 63.813
# Titik data 119 (Fitur: [-0.03774496 -0.35310783  0.08836898 -0.13797282]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.193, Inertia sementara: 64.006
# Titik data 120 (Fitur: [-0.25550435 -0.4183773  -0.13025219 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.037, Inertia sementara: 64.043
# Titik data 121 (Fitur: [-0.14021997 -0.25520363 -0.04970755 -0.13797282]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.074, Inertia sementara: 64.118
# Titik data 122 (Fitur: [-0.30674186 -0.3204731  -0.14175857 -0.17053064]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.024, Inertia sementara: 64.142
# Titik data 123 (Fitur: [-0.03774496 -0.3204731   0.06535622 -0.17053064]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.168, Inertia sementara: 64.309
# Titik data 124 (Fitur: [-0.21707622 -0.33679047 -0.14175857 -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.024, Inertia sementara: 64.333
# Titik data 125 (Fitur: [-0.16583872 -0.23888626 -0.04970755 -0.15967803]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.065, Inertia sementara: 64.398
# Titik data 126 (Fitur: [-0.10179184 -0.25520363 -0.01518842 -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.092, Inertia sementara: 64.490
# Titik data 127 (Fitur: [-0.2298856  -0.3204731  -0.15326494 -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.018, Inertia sementara: 64.508
# Titik data 128 (Fitur: [-0.24269498 -0.28783836 -0.14175857 -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.018, Inertia sementara: 64.526
# Titik data 129 (Fitur: [-0.20426685 -0.3204731  -0.06121393 -0.15967803]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.054, Inertia sementara: 64.580
# Titik data 130 (Fitur: [-0.10179184 -0.28783836 -0.03820117 -0.21394107]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.079, Inertia sementara: 64.659
# Titik data 131 (Fitur: [-0.07617309 -0.3204731  -0.00368204 -0.18138325]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.110, Inertia sementara: 64.769
# Titik data 132 (Fitur: [-0.01212621 -0.15729942  0.03083709 -0.17053064]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.172, Inertia sementara: 64.941
# Titik data 133 (Fitur: [-0.20426685 -0.3204731  -0.06121393 -0.14882543]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.056, Inertia sementara: 64.997
# Titik data 134 (Fitur: [-0.21707622 -0.3204731  -0.11874581 -0.22479368]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.025, Inertia sementara: 65.022
# Titik data 135 (Fitur: [-0.24269498 -0.35310783 -0.06121393 -0.23564629]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.046, Inertia sementara: 65.068
# Titik data 136 (Fitur: [-0.03774496 -0.28783836 -0.00368204 -0.13797282]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.132, Inertia sementara: 65.200
# Titik data 137 (Fitur: [-0.21707622 -0.22256889 -0.06121393 -0.12712021]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.061, Inertia sementara: 65.261
# Titik data 138 (Fitur: [-0.20426685 -0.271521   -0.0727203  -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.043, Inertia sementara: 65.304
# Titik data 139 (Fitur: [-0.25550435 -0.28783836 -0.15326494 -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.015, Inertia sementara: 65.319
# Titik data 140 (Fitur: [-0.14021997 -0.271521   -0.08422668 -0.15967803]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.056, Inertia sementara: 65.375
# Titik data 141 (Fitur: [-0.16583872 -0.271521   -0.06121393 -0.12712021]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.066, Inertia sementara: 65.441
# Titik data 142 (Fitur: [-0.14021997 -0.271521   -0.11874581 -0.13797282]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.050, Inertia sementara: 65.491
# Titik data 143 (Fitur: [-0.2811231  -0.33679047 -0.11874581 -0.18138325]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.029, Inertia sementara: 65.519
# Titik data 144 (Fitur: [-0.15302934 -0.25520363 -0.02669479 -0.13797282]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.081, Inertia sementara: 65.601
# Titik data 145 (Fitur: [-0.16583872 -0.23888626 -0.04970755 -0.1162676 ]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.075, Inertia sementara: 65.676
# Titik data 146 (Fitur: [-0.16583872 -0.28783836 -0.10723943 -0.13797282]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.047, Inertia sementara: 65.723
# Titik data 147 (Fitur: [-0.21707622 -0.3694252  -0.13025219 -0.18138325]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.033, Inertia sementara: 65.755
# Titik data 148 (Fitur: [-0.19145747 -0.28783836 -0.10723943 -0.17053064]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.036, Inertia sementara: 65.791
# Titik data 149 (Fitur: [-0.2298856  -0.22256889 -0.08422668 -0.13797282]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.049, Inertia sementara: 65.840
# Titik data 150 (Fitur: [-0.26831373 -0.28783836 -0.11874581 -0.19223586]), Klaster: 0, Centroid: [-0.26849937 -0.27873375 -0.2602409  -0.25208248], Jarak kuadrat: 0.024, Inertia sementara: 65.864
#
# Total Inertia Manual: 65.864
# Inertia dari sklearn: 65.864
# ==================================================

# %% [markdown]
# ## **Model Plotting Diagram Elbow Method**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_cols].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Hitung inertia untuk berbagai nilai k
inertias = []
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertias.append(kmeans.inertia_)

# 4. Plot Elbow Diagram
plt.figure(figsize=(9, 6))
plt.plot(K_range, inertias, 'bo-', markersize=8, label='Inertia')
plt.title("Metode Elbow - Menentukan Jumlah Klaster Optimal")
plt.xlabel("Jumlah Klaster (k)")
plt.ylabel("Inertia")
plt.xticks(K_range)
plt.grid(True)

# Tambahkan label inertia di tiap titik
for i, inertia in enumerate(inertias):
    plt.text(K_range[i], inertias[i] + 1, f"{inertia:.2f}", ha='center', fontsize=9)

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Menghitung Silhouette Score untuk Jumlah Cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_cols].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk melakukan K-Means dan menghitung Silhouette Score
def perform_kmeans_with_silhouette(X_scaled, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)

    # Menghitung Silhouette Score
    silhouette_avg = silhouette_score(X_scaled, labels)

    # Centroid dari masing-masing klaster
    centroids = kmeans.cluster_centers_

    # Output hasil untuk klaster k
    print(f"\n=== Hasil K-Means dengan {k} Klaster ===")
    print(f"Centroids:\n{centroids}")
    print(f"Silhouette Score untuk {k} klaster: {silhouette_avg:.3f}")

    return silhouette_avg

# 4. Melakukan clustering dan menghitung Silhouette Score untuk k=2, 3, dan 4
silhouette_scores = []
k_values = [2, 3, 4]

for k in k_values:
    score = perform_kmeans_with_silhouette(X_scaled, k)
    silhouette_scores.append(score)

# 5. Menentukan k dengan Silhouette Score terbaik
best_k = k_values[np.argmax(silhouette_scores)]
best_score = max(silhouette_scores)
print(f"\n>>> Jumlah cluster terbaik dengan dengan Silhouette Score mendekati 1 adalah k = {best_k} (dengan score = {best_score:.3f})")

# 6. Plot Silhouette Scores
plt.figure(figsize=(8, 5))
plt.plot(k_values, silhouette_scores, 'bo-', markersize=8)
plt.title("Silhouette Score untuk Jumlah Klaster yang Berbeda")
plt.xlabel("Jumlah Klaster (k)")
plt.ylabel("Silhouette Score")
plt.xticks(k_values)
plt.grid(True)
plt.show()
# Out:
# === Hasil K-Means dengan 2 Klaster ===
# Centroids:
# [[-0.26342958 -0.26471231 -0.24581264 -0.24282931]
#  [ 3.32879194  3.34500102  3.10617787  3.06847946]]
# Silhouette Score untuk 2 klaster: 0.913
#
# === Hasil K-Means dengan 3 Klaster ===
# Centroids:
# [[-0.26849937 -0.27873375 -0.2602409  -0.25208248]
#  [ 4.33793787  3.34114419  4.24447237  3.59532423]
#  [ 2.19474628  3.10850515  2.09869743  2.40153738]]
# Silhouette Score untuk 3 klaster: 0.884
#
# === Hasil K-Means dengan 4 Klaster ===
# Centroids:
# [[-0.26849937 -0.27873375 -0.2602409  -0.25208248]
#  [ 4.26940771  3.44475947  4.30257957  2.90347049]
#  [ 2.26153802  3.29654338  1.95240206  1.88965605]
#  [ 3.20302716  2.45347939  3.49425659  5.91778228]]
# Silhouette Score untuk 4 klaster: 0.882
#
# >>> Jumlah cluster terbaik dengan dengan Silhouette Score mendekati 1 adalah k = 2 (dengan score = 0.913)
